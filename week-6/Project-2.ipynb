# %%
admitted = []
not_admitted = []
passing_grades = ["A1","B2","B3","C4","C5","C6"]
failing_grades = ["D7","E8","F9"]

def cos():
    mth = input("YOUR GRADE IN MATH")
    eng = input("YOUR GRADE IN ENGLISH")
    phy = input("YOUR GRADE IN PHYSICS")
    chem = input("YOUR GRADE IN CHEMISTRY")
    dp = input("YOUR GRADE IN DATA PROCESSING")
    print("")

    if mth in passing_grades and eng in passing_grades and chem in passing_grades and dp in passing_grades and js > 249:
        admitted.append(name)
        print("congratulations",name,", you have been selected to join our COMPUTER SCIENCE programme")
        print("\n")
    elif mth in failing_grades and eng in failing_grades and chem in failing_grades and dp in failing_grades or js < 250:
        not_admitted.append(name)
        print("unfortunately you do not qualify for this programme")
        print("\n")
    else:
        print("invalid entry of data, please check your records and try again")
        print("\n")

def mscm():
    mth = input("YOUR GRADE IN MATH")
    eng = input("YOUR GRADE IN ENGLISH")
    lit = input("YOUR GRADE IN LITERATURE")
    gov = input("YOUR GRADE IN GOVERNMENT")
    dp = input("YOUR GRADE IN DATA PROCESSING")
    if mth in passing_grades and eng in passing_grades and lit in passing_grades and gov in passing_grades and dp in passing_grades and js < 240:
        admitted.append(name)
        print("congratulations",name,", you have been selected to join our MASS COMMUNICATION programme")
        print("\n")
        return
    elif mth in failing_grades or eng in failing_grades or lit in failing_grades or gov in failing_grades or dp in failing_grades or js < 239:
        not_admitted.append(name)
        print("unfortunately you do not qualify for this programme")
        print("\n")
        return
    else:
        print("Invalid entry of data, please check your records and try again")
        print("\n")

count = int(input("HOW MANY PEOPLE WILL BE USING THIS SYSTEM"))

i = 0
while i < count:
    name = input("ENTER YOUR NAME: ")
    print("")

    js = int(input("ENTER YOUR JAMBSCORE: "))
    print("")

    course = input("ENTER YOUR PREFERRED COURSE")
    if course == "MASS COMMUNICATION":
        mscm()
    elif course == "COMPUTER SCIENCE":
        cos()
    else:
        print("WE DO NOT OFFER THIS PROGRAMME AVAILABLE YET. PLEASE TRY AN EXISTING PROGRAMME")

i = i + 1
if i == count:
    break

print("NAMES OF ADMITTED STUDENTS: ")
print(admitted)
print("\n")

print("NAMES OF STUDENTS WHO DID NOT GET ADMITTED: ")
print(not_admitted)
